# %% [markdown]
# <a href="https://colab.research.google.com/github/abiflynn/unsupervised_machine_learning/blob/main/song_analysis/5000_songs_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read in the csv
music_df = pd.read_csv("/content/drive/MyDrive/WBS CODING/Projects/Project 6: (Unsupervised Machine Learning) /df_audio_features_5000")
#replace the paces in the coloumn names
music_df.columns = music_df.columns.str.replace(' ', '')
#set the index to name 
music_df = music_df.set_index('name')
#drop the columns you know need
music_df.drop(['id', 'html', 'artist', 'type', 'key', 'mode', 'time_signature'], axis=1, inplace=True)
music_df.head()
# Out:
#                                                     danceability  energy  \
# name
# Se Eu Quiser Falar Com Deus                    ...         0.658  0.2590
# Saudade De Bahia                               ...         0.742  0.3990
# Canta Canta, Minha Gente                       ...         0.851  0.7300
# Mulher Eu Sei                                  ...         0.705  0.0502
# Rosa Morena                                    ...         0.651  0.1190
#
#                                                     loudness  speechiness  \
# name
# Se Eu Quiser Falar Com Deus                    ...   -13.141       0.0705
# Saudade De Bahia                               ...   -12.646       0.0346
# Canta Canta, Minha Gente                       ...   -11.048       0.3470
# Mulher Eu Sei                                  ...   -18.115       0.0471
# Rosa Morena                                    ...   -19.807       0.0380
#
#                                                     acousticness  \
# ...

# %% [markdown]
# # Scaling

# %% [markdown]
# ### Min Max Scaling

# %%
# Import MinMax Scaler
from sklearn.preprocessing import MinMaxScaler

# Create DataFrame of MinMax scaled values
music_min_max_df = MinMaxScaler().fit_transform(music_df)
music_minmax = pd.DataFrame(music_min_max_df, columns=music_df.columns, index=music_df.index)
music_minmax.head()
# Out:
#                                                     danceability  energy  \
# name
# Se Eu Quiser Falar Com Deus                    ...      0.680455  0.2590
# Saudade De Bahia                               ...      0.767322  0.3990
# Canta Canta, Minha Gente                       ...      0.880041  0.7300
# Mulher Eu Sei                                  ...      0.729059  0.0502
# Rosa Morena                                    ...      0.673216  0.1190
#
#                                                     loudness  speechiness  \
# name
# Se Eu Quiser Falar Com Deus                    ...  0.763897     0.076797
# Saudade De Bahia                               ...  0.771967     0.037691
# Canta Canta, Minha Gente                       ...  0.798018     0.377996
# Mulher Eu Sei                                  ...  0.682811     0.051307
# Rosa Morena                                    ...  0.655228     0.041394
#
#                                                     acousticness  \
# ...

# %%
# Stating that we want 10 plots
fig, [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10] = plt.subplots(nrows=1, ncols=10)
fig.set_size_inches(50, 7)

# Plotting the 10 plots
sns.histplot(music_minmax.iloc[:,0], bins=10, kde=True, ax=ax1);
sns.histplot(music_minmax.iloc[:,1], bins=10, kde=True, ax=ax2);
sns.histplot(music_minmax.iloc[:,2], bins=10, kde=True, ax=ax3);
sns.histplot(music_minmax.iloc[:,3], bins=10, kde=True, ax=ax4);
sns.histplot(music_minmax.iloc[:,4], bins=10, kde=True, ax=ax5);
sns.histplot(music_minmax.iloc[:,5], bins=10, kde=True, ax=ax6);
sns.histplot(music_minmax.iloc[:,6], bins=10, kde=True, ax=ax7);
sns.histplot(music_minmax.iloc[:,7], bins=10, kde=True, ax=ax8);
sns.histplot(music_minmax.iloc[:,8], bins=10, kde=True, ax=ax9);
sns.histplot(music_minmax.iloc[:,9], bins=10, kde=True, ax=ax10);

# Adding titles to the plots
# ax1.set_title('Distribution of danceability without scaling')
# ax2.set_title('Distribution of danceability with MinMax scaling')

plt.show()

# %% [markdown]
# ### Standard Scaling

# %%
# Import Standard Scaler
from sklearn.preprocessing import StandardScaler

# Create DataFrame of Standar scaled values
music_standard_df = StandardScaler().fit_transform(music_df)
music_standard = pd.DataFrame(music_standard_df, columns=music_df.columns, index=music_df.index)
music_standard.head()
# Out:
#                                                     danceability    energy  \
# name
# Se Eu Quiser Falar Com Deus                    ...      0.681116 -1.368556
# Saudade De Bahia                               ...      1.066401 -0.882963
# Canta Canta, Minha Gente                       ...      1.566355  0.265117
# Mulher Eu Sei                                  ...      0.896692 -2.092782
# Rosa Morena                                    ...      0.649009 -1.854148
#
#                                                     loudness  speechiness  \
# name
# Se Eu Quiser Falar Com Deus                    ... -0.604187    -0.178099
# Saudade De Bahia                               ... -0.525544    -0.682409
# Canta Canta, Minha Gente                       ... -0.271661     3.706071
# Mulher Eu Sei                                  ... -1.394432    -0.506814
# Rosa Morena                                    ... -1.663249    -0.634647
#
# ...

# %%
# Stating that we want 10 plots
fig, [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10] = plt.subplots(nrows=1, ncols=10)
fig.set_size_inches(50, 7)

# Plotting the 10 plots
sns.histplot(music_standard.iloc[:,0], bins=10, kde=True, ax=ax1);
sns.histplot(music_standard.iloc[:,1], bins=10, kde=True, ax=ax2);
sns.histplot(music_standard.iloc[:,2], bins=10, kde=True, ax=ax3);
sns.histplot(music_standard.iloc[:,3], bins=10, kde=True, ax=ax4);
sns.histplot(music_standard.iloc[:,4], bins=10, kde=True, ax=ax5);
sns.histplot(music_standard.iloc[:,5], bins=10, kde=True, ax=ax6);
sns.histplot(music_standard.iloc[:,6], bins=10, kde=True, ax=ax7);
sns.histplot(music_standard.iloc[:,7], bins=10, kde=True, ax=ax8);
sns.histplot(music_standard.iloc[:,8], bins=10, kde=True, ax=ax9);
sns.histplot(music_standard.iloc[:,9], bins=10, kde=True, ax=ax10);

plt.show()

# %% [markdown]
# ### Robust Scaling

# %%
# Import Robust Scaler
from sklearn.preprocessing import RobustScaler

# Create DataFrame of Robust scaled values
music_robust_df = RobustScaler().fit_transform(music_df)
music_robust = pd.DataFrame(music_robust_df, columns=music_df.columns, index=music_df.index)
music_robust.head()
# Out:
#                                                     danceability    energy  \
# name
# Se Eu Quiser Falar Com Deus                    ...      0.313984 -1.157005
# Saudade De Bahia                               ...      0.535620 -0.818841
# Canta Canta, Minha Gente                       ...      0.823219 -0.019324
# Mulher Eu Sei                                  ...      0.437995 -1.661353
# Rosa Morena                                    ...      0.295515 -1.495169
#
#                                                     loudness  speechiness  \
# name
# Se Eu Quiser Falar Com Deus                    ... -0.955541     0.246438
# Saudade De Bahia                               ... -0.874033    -0.355407
# Canta Canta, Minha Gente                       ... -0.610901     4.881811
# Mulher Eu Sei                                  ... -1.774576    -0.145851
# Rosa Morena                                    ... -2.053186    -0.298407
#
# ...

# %%
# Stating that we want 10 plots
fig, [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10] = plt.subplots(nrows=1, ncols=10)
fig.set_size_inches(50, 7)

# Plotting the 10 plots
sns.histplot(music_robust.iloc[:,0], bins=10, kde=True, ax=ax1);
sns.histplot(music_robust.iloc[:,1], bins=10, kde=True, ax=ax2);
sns.histplot(music_robust.iloc[:,2], bins=10, kde=True, ax=ax3);
sns.histplot(music_robust.iloc[:,3], bins=10, kde=True, ax=ax4);
sns.histplot(music_robust.iloc[:,4], bins=10, kde=True, ax=ax5);
sns.histplot(music_robust.iloc[:,5], bins=10, kde=True, ax=ax6);
sns.histplot(music_robust.iloc[:,6], bins=10, kde=True, ax=ax7);
sns.histplot(music_robust.iloc[:,7], bins=10, kde=True, ax=ax8);
sns.histplot(music_robust.iloc[:,8], bins=10, kde=True, ax=ax9);
sns.histplot(music_robust.iloc[:,9], bins=10, kde=True, ax=ax10);

plt.show()

# %% [markdown]
# # Transformers

# %% [markdown]
# ### Quantile Transformer

# %%
# Import Quantile Transformer
from sklearn.preprocessing import QuantileTransformer

# Create DataFrame of Quantile transformed values
music_quantile_df = QuantileTransformer(n_quantiles=len(music_df.iloc[:,1])).fit_transform(music_df)
music_quantile = pd.DataFrame(music_quantile_df, columns=music_df.columns, index=music_df.index)
music_quantile.head()
# Out:
#                                                     danceability    energy  \
# name
# Se Eu Quiser Falar Com Deus                    ...      0.701662  0.145969
# Saudade De Bahia                               ...      0.834066  0.206916
# Canta Canta, Minha Gente                       ...      0.962457  0.490638
# Mulher Eu Sei                                  ...      0.780378  0.037830
# Rosa Morena                                    ...      0.689243  0.079862
#
#                                                     loudness  speechiness  \
# name
# Se Eu Quiser Falar Com Deus                    ...  0.187142     0.615399
# Saudade De Bahia                               ...  0.203764     0.155808
# Canta Canta, Minha Gente                       ...  0.260986     0.986626
# Mulher Eu Sei                                  ...  0.096485     0.399217
# Rosa Morena                                    ...  0.075468     0.230225
#
# ...

# %%
# Stating that we want 10 plots
fig, [ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10] = plt.subplots(nrows=1, ncols=10, figsize=(50,10))
#fig.set_size_inches(50,15)

# Plotting the 10 plots
sns.histplot(music_quantile.iloc[:,0], bins=10, kde=True, ax=ax1);
sns.histplot(music_quantile.iloc[:,1], bins=10, kde=True, ax=ax2);
sns.histplot(music_quantile.iloc[:,2], bins=10, kde=True, ax=ax3);
sns.histplot(music_quantile.iloc[:,3], bins=10, kde=True, ax=ax4);
sns.histplot(music_quantile.iloc[:,4], bins=10, kde=True, ax=ax5);
sns.histplot(music_quantile.iloc[:,5], bins=10, kde=True, ax=ax6);
sns.histplot(music_quantile.iloc[:,6], bins=10, kde=True, ax=ax7);
sns.histplot(music_quantile.iloc[:,7], bins=10, kde=True, ax=ax8);
sns.histplot(music_quantile.iloc[:,8], bins=10, kde=True, ax=ax9);
sns.histplot(music_quantile.iloc[:,9], bins=10, kde=True, ax=ax10);

plt.show()

# %% [markdown]
# ### Power Transformer

# %%
# Import Power Transformer
from sklearn.preprocessing import PowerTransformer

# Create DataFrame of Power transformed values
music_power_df = PowerTransformer().fit_transform(music_df)
music_power = pd.DataFrame(music_power_df, columns=music_df.columns, index=music_df.index)
music_power.head()
# Out:
#                                                     danceability    energy  \
# name
# Se Eu Quiser Falar Com Deus                    ...      0.671946 -1.366485
# Saudade De Bahia                               ...      1.072584 -1.037604
# Canta Canta, Minha Gente                       ...      1.601005  0.100674
# Mulher Eu Sei                                  ...      0.895392 -1.721861
# Rosa Morena                                    ...      0.638825 -1.620882
#
#                                                     loudness  speechiness  \
# name
# Se Eu Quiser Falar Com Deus                    ... -0.872257     0.203888
# Saudade De Bahia                               ... -0.806268    -1.043567
# Canta Canta, Minha Gente                       ... -0.574711     1.977698
# Mulher Eu Sei                                  ... -1.425873    -0.528874
# Rosa Morena                                    ... -1.580209    -0.893477
#
# ...

# %%
# Stating that we want two plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plotting the two plots
sns.histplot(data=music_df.iloc[:,7], bins=10, kde=True, ax=ax1);
sns.histplot(data=music_power.iloc[:,7], bins=10, kde=True, ax=ax2);

# Adding titles to the plots
ax1.set_title('Distribution of x without scaling')
ax2.set_title('Distribution of x with Power transforming')

plt.show()

# %% [markdown]
# # SciKit Learn - Euclidean Distance

# %%
from sklearn.metrics import pairwise_distances
#not using scaling 
music_euclidean_distance = pd.DataFrame(pairwise_distances(music_df), index=music_df.index, columns=music_df.index)
music_euclidean_distance.head()
# Out:
# name                                                Se Eu Quiser Falar Com Deus                                                                                                                                                        \
# name
# Se Eu Quiser Falar Com Deus                    ...                                           0.000000
# Saudade De Bahia                               ...                                       64346.001682
# Canta Canta, Minha Gente                       ...                                      103946.001366
# Mulher Eu Sei                                  ...                                       69986.000271
# Rosa Morena                                    ...                                       17467.004491
#
# name                                                Saudade De Bahia                                                                                                                                                                   \
# ...

# %% [markdown]
# # K-Means (Comparing Two Parts of Data) (MinMax Scaler)

# %% [markdown]
# ### Visualise the Data

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(data=music_df, x='danceability', y='energy')
plt.title('Looking for a relation between x and x')
plt.show()

# %% [markdown]
# ### Data Scaling

# %%
#if only comparing two varibles use 
music_two = music_df[['danceability','energy']]
music_two.head()
# Out:
#                                                     danceability  energy
# name
# Se Eu Quiser Falar Com Deus                    ...         0.658  0.2590
# Saudade De Bahia                               ...         0.742  0.3990
# Canta Canta, Minha Gente                       ...         0.851  0.7300
# Mulher Eu Sei                                  ...         0.705  0.0502
# Rosa Morena                                    ...         0.651  0.1190

# %%
music_two.describe()
# Out:
#        danceability       energy
# count   5235.000000  5235.000000
# mean       0.509503     0.653565
# std        0.218041     0.288335
# min        0.000000     0.000000
# 25%        0.309000     0.479000
# 50%        0.539000     0.738000
# 75%        0.688000     0.893000
# max        0.967000     1.000000

# %%
from sklearn.preprocessing import MinMaxScaler

music_two_scaled = MinMaxScaler().fit_transform(music_two)

# %%
type(music_two_scaled)
# Out:
# numpy.ndarray

# %%
music_two_scaled = pd.DataFrame(music_two_scaled) #turn it back into a dataframe
music_two_scaled.columns = ['danceability','energy']
music_two_scaled[:5]
# Out:
#    danceability  energy
# 0      0.680455  0.2590
# 1      0.767322  0.3990
# 2      0.880041  0.7300
# 3      0.729059  0.0502
# 4      0.673216  0.1190

# %% [markdown]
# ### K-Means

# %%
from sklearn.cluster import KMeans

# Based on the quick look to the scatter plot, 
# we are going to assume there can be 2 different clusters k = 3. 
kmeans = KMeans(n_clusters=2)
kmeans.fit(music_two_scaled)  # Compute k-means clustering
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[0.45410125, 0.23648816],
#        [0.55287033, 0.80242794]])

# %%
cl_pos = pd.DataFrame(kmeans.cluster_centers_)
cl_pos.columns = ['danceability','energy']
cl_pos
# Out:
#    danceability    energy
# 0      0.454101  0.236488
# 1      0.552870  0.802428

# %% [markdown]
# ### K-Means Plot

# %%
# create plot dataframe
plot_data = pd.DataFrame(music_two_scaled)
plot_data.columns = ['danceability','energy']
plot_data['cluster'] = kmeans.labels_

# size and plot titles
fig, ax = plt.subplots(figsize=(10, 8))
plt.title('Visualising clusters')
plt.xlabel('danceability normalised')
plt.ylabel('energy normalised')

# scatter plot
sns.scatterplot(data=plot_data, x='danceability', y='energy', hue='cluster', palette='Set2', s=75)
sns.scatterplot(data=cl_pos, x='danceability', y='energy', color='red', s=250)
plt.show()

# %% [markdown]
# # K-Means (All Data) (Standard Scaler)

# %%
from sklearn.preprocessing import StandardScaler
music_df_standard = StandardScaler().fit_transform(music_df)

kmeans_all = KMeans(n_clusters=12)
kmeans_all.fit(music_df_standard)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=12)

# %%
kmeans_all.cluster_centers_
# Out:
# array([[ 1.0277819 ,  0.20239079,  0.40447814, -0.27596308, -0.29402781,
#         -0.61242678, -0.28683183,  1.17090457, -0.32480209, -0.22461335],
#        [-1.10338609, -1.92918614, -2.35634277, -0.53023672,  1.82906793,
#          1.39189226, -0.38959544, -1.15029569, -1.37578549,  0.22043183],
#        [-1.2482376 ,  0.89188274,  0.17241984,  0.2312518 , -0.79016116,
#          1.30434645,  0.0721283 , -0.71435359,  1.36776941,  0.15086029],
#        [-1.0421713 ,  0.97303788,  0.4196754 ,  0.66325778, -0.79018906,
#         -0.39673224, -0.04683913, -0.8744958 , -0.09923856,  0.10011328],
#        [ 0.16091231,  0.2268056 ,  0.37123571, -0.16462769, -0.07974885,
#         -0.54143155, -0.16697844,  0.93301965,  1.57348343, -0.29516064],
#        [ 0.21288549,  0.30229271,  0.32399569,  0.08744013, -0.16469003,
#         -0.41361494,  3.1530054 ,  0.19250563,  0.10790611, -0.03564056],
#        [-1.47397972, -1.75713002, -1.91692408, -0.50562283,  1.62925679,
# ...

# %% [markdown]
# ### Plot 1 (2D)

# %%
cl_pos = pd.DataFrame(kmeans_all.cluster_centers_)
cl_pos.columns = ['danceability',	'energy',	'loudness',	'speechiness',	'acousticness',	'instrumentalness', 'liveness',	'valence', 'tempo',	'duration_ms']
cl_pos

fig, ax = plt.subplots(figsize=(10, 8))

plot_data = pd.DataFrame(music_df_standard)
plot_data.columns = ['danceability',	'energy',	'loudness',	'speechiness',	'acousticness',	'instrumentalness', 'liveness',	'valence', 'tempo',	'duration_ms']
plot_data['cluster'] = kmeans_all.labels_

sns.scatterplot(data=plot_data, x='danceability', y='energy', hue='cluster', palette='Set2', s=75)
sns.scatterplot(data=cl_pos, x='danceability', y='energy', color='red', s=250)
plt.show()

# %% [markdown]
# ### Plot 3 (all data)

# %%
# Source: https://www.python-graph-gallery.com/391-radar-chart-with-several-individuals
# Libraries
from math import pi
 
# Set data
radar_df = cl_pos.reset_index().rename(columns={'index':'cluster'})
 
# ------- PART 1: Create background
 
# number of variable
categories= radar_df.columns.tolist()[1:]
# list(df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
plt.gcf().set_size_inches(12,12)

# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks(ticks=None, labels=None)
# plt.ylim(0,40)
 

# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't make a loop, because plotting more than 3 groups makes the chart unreadable

# Ind1
values=radar_df.loc[0].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 0")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind2
values=radar_df.loc[1].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 1")
#ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values=radar_df.loc[2].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 2")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind4
values=radar_df.loc[3].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 3")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind5
values=radar_df.loc[4].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 4")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind6
values=radar_df.loc[5].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 5")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind7
values=radar_df.loc[6].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 6")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind8
values=radar_df.loc[7].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 7")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind9
values=radar_df.loc[8].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 8")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind10
values=radar_df.loc[9].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 9")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind11
values=radar_df.loc[10].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 10")
#ax.fill(angles, values, 'b', alpha=0.1)

# Ind12
values=radar_df.loc[11].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 11")
#ax.fill(angles, values, 'b', alpha=0.1)

# # Add legend
#plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Show the graph
plt.show()

# %% [markdown]
# # K-Means Choosing Clusters

# %% [markdown]
# ### Elbow Method - Using inertia

# %%
from sklearn.preprocessing import StandardScaler
music_df_standard = StandardScaler().fit_transform(music_df)

kmeans_all = KMeans(n_clusters=3)
music_kmeans = kmeans_all.fit(music_df_standard)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
music_kmeans.inertia_
# Out:
# 32385.170638324857

# %%
max_k = 15
inertia = []

for k in range(1, max_k): 
    inertia.append(KMeans(n_clusters=k).fit(music_df).inertia_)

fig, ax = plt.subplots(figsize=(12, 6))
plt.title(f'Inertia evolution from 1 cluster to {max_k} cluster')
sns.lineplot(x=range(1, max_k), y=inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %% [markdown]
# ### Silhouette Method

# %%
from sklearn.metrics import silhouette_score
silhouette_score(music_df, music_kmeans.labels_)
# Out:
# 0.03008540338130066

# %%
max_k = 15
sil_score = []

food_norm = MinMaxScaler().fit_transform(music_df)

for k in range(2, max_k): 
    labels = KMeans(n_clusters=k).fit(music_df).labels_
    sil_score.append(silhouette_score(music_df, labels))

plt.title(f'Silhouette score evolution from 2 cluster to {max_k} clusters')
sns.lineplot(x=range(2, max_k), y=sil_score, marker='o')
plt.show()
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...
