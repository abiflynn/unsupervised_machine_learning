# %% [markdown]
# <a href="https://colab.research.google.com/github/abiflynn/unsupervised_machine_learning/blob/main/song_analysis/1000_songs_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
music_df = pd.read_csv('df_audio_features_1000', index_col='name')
music_df.drop(['id', 'html', 'artist', 'type'], axis=1, inplace=True)
music_df.head()
# Out:
#                                               danceability  energy  key  \
# name
# All Shook Up                                         0.624   0.468   10
# I've Got You Under My Skin - Remastered 1998         0.585   0.247    1
# Smoke Gets In Your Eyes                              0.290   0.227    3
# What'd I Say, Pt. 1 & 2                              0.540   0.681    4
# Dream A Little Dream Of Me                           0.455   0.167    0
#
#                                               loudness  mode  speechiness  \
# name
# All Shook Up                                   -12.162     1       0.1320
# I've Got You Under My Skin - Remastered 1998   -12.612     1       0.0400
# Smoke Gets In Your Eyes                        -13.060     1       0.0311
# What'd I Say, Pt. 1 & 2                         -5.440     1       0.0508
# Dream A Little Dream Of Me                     -13.613     1       0.0739
#
#                                               acousticness  instrumentalness  \
# name
# All Shook Up                                         0.881          0.000006
# I've Got You Under My Skin - Remastered 1998         0.452          0.000009
# Smoke Gets In Your Eyes                              0.944          0.000079
# What'd I Say, Pt. 1 & 2                              0.808          0.000000
# Dream A Little Dream Of Me                           0.918          0.000000
#
#                                               liveness  valence    tempo  \
# name
# All Shook Up                                     0.144    0.952   74.139
# I've Got You Under My Skin - Remastered 1998     0.107    0.591  127.150
# Smoke Gets In Your Eyes                          0.617    0.224  114.278
# What'd I Say, Pt. 1 & 2                          0.162    0.794   88.385
# Dream A Little Dream Of Me                       0.173    0.404   76.118
#
#                                               duration_ms  time_signature
# name
# All Shook Up                                       117080               4
# I've Got You Under My Skin - Remastered 1998       223760               4
# Smoke Gets In Your Eyes                            157293               4
# What'd I Say, Pt. 1 & 2                            307053               4
# Dream A Little Dream Of Me                         185067               4

# %% [markdown]
# # Scaling

# %% [markdown]
# ### Min Max Scaling

# %%
# Import MinMax Scaler
from sklearn.preprocessing import MinMaxScaler

# Create DataFrame of MinMax scaled values
music_min_max_df = MinMaxScaler().fit_transform(music_df)
music_minmax = pd.DataFrame(music_min_max_df, columns=music_df.columns, index=music_df.index)
music_minmax.head()
# Out:
#                                               danceability    energy  \
# name
# All Shook Up                                      0.624060  0.469869
# I've Got You Under My Skin - Remastered 1998      0.580938  0.247977
# Smoke Gets In Your Eyes                           0.254755  0.227896
# What'd I Say, Pt. 1 & 2                           0.531181  0.683728
# Dream A Little Dream Of Me                        0.437196  0.167654
#
#                                                    key  loudness  mode  \
# name
# All Shook Up                                  0.909091  0.708800   1.0
# I've Got You Under My Skin - Remastered 1998  0.090909  0.698907   1.0
# Smoke Gets In Your Eyes                       0.272727  0.689059   1.0
# What'd I Say, Pt. 1 & 2                       0.363636  0.856565   1.0
# Dream A Little Dream Of Me                    0.000000  0.676903   1.0
#
#                                               speechiness  acousticness  \
# name
# All Shook Up                                     0.196816      0.884538
# I've Got You Under My Skin - Remastered 1998     0.030391      0.453814
# Smoke Gets In Your Eyes                          0.014291      0.947791
# What'd I Say, Pt. 1 & 2                          0.049928      0.811245
# Dream A Little Dream Of Me                       0.091715      0.921687
#
#                                               instrumentalness  liveness  \
# name
# All Shook Up                                          0.000006  0.127865
# I've Got You Under My Skin - Remastered 1998          0.000009  0.089495
# Smoke Gets In Your Eyes                               0.000081  0.618376
# What'd I Say, Pt. 1 & 2                               0.000000  0.146531
# Dream A Little Dream Of Me                            0.000000  0.157938
#
#                                                valence     tempo  duration_ms  \
# name
# All Shook Up                                  0.965817  0.156106     0.014474
# I've Got You Under My Skin - Remastered 1998  0.591879  0.494567     0.042899
# Smoke Gets In Your Eyes                       0.211726  0.412383     0.025189
# What'd I Say, Pt. 1 & 2                       0.802155  0.247063     0.065093
# Dream A Little Dream Of Me                    0.398177  0.168742     0.032589
#
#                                               time_signature
# name
# All Shook Up                                            0.75
# I've Got You Under My Skin - Remastered 1998            0.75
# Smoke Gets In Your Eyes                                 0.75
# What'd I Say, Pt. 1 & 2                                 0.75
# Dream A Little Dream Of Me                              0.75

# %%
# Stating that we want two plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plotting the two plots
sns.histplot(data=music_df.iloc[:,2], bins=10, kde=True, ax=ax1);
sns.histplot(music_minmax.iloc[:,2], bins=10, kde=True, ax=ax2);

# Adding titles to the plots
ax1.set_title('Distribution of danceability without scaling')
ax2.set_title('Distribution of danceability with MinMax scaling')

plt.show()

# %% [markdown]
# ### Standard Scaling

# %%
# Import Standard Scaler
from sklearn.preprocessing import StandardScaler

# Create DataFrame of Standar scaled values
music_standard_df = StandardScaler().fit_transform(music_df)
music_standard = pd.DataFrame(music_standard_df, columns=music_df.columns, index=music_df.index)
music_standard.head()
# Out:
#                                               danceability    energy  \
# name
# All Shook Up                                      0.388299 -0.093112
# I've Got You Under My Skin - Remastered 1998      0.210312 -0.877303
# Smoke Gets In Your Eyes                          -1.136000 -0.948270
# What'd I Say, Pt. 1 & 2                           0.004942  0.662692
# Dream A Little Dream Of Me                       -0.382978 -1.161173
#
#                                                    key  loudness      mode  \
# name
# All Shook Up                                  1.368799 -0.152503  0.712638
# I've Got You Under My Skin - Remastered 1998 -1.173788 -0.217004  0.712638
# Smoke Gets In Your Eyes                      -0.608769 -0.281218  0.712638
# What'd I Say, Pt. 1 & 2                      -0.326259  0.810992  0.712638
# Dream A Little Dream Of Me                   -1.456298 -0.360482  0.712638
#
#                                               speechiness  acousticness  \
# name
# All Shook Up                                     0.530704      1.098048
# I've Got You Under My Skin - Remastered 1998    -0.537044     -0.047460
# Smoke Gets In Your Eyes                         -0.640337      1.266269
# What'd I Say, Pt. 1 & 2                         -0.411700      0.903124
# Dream A Little Dream Of Me                      -0.143602      1.196844
#
#                                               instrumentalness  liveness  \
# name
# All Shook Up                                         -0.560144 -0.208221
# I've Got You Under My Skin - Remastered 1998         -0.560137 -0.461722
# Smoke Gets In Your Eyes                              -0.559927  3.032485
# What'd I Say, Pt. 1 & 2                              -0.560163 -0.084896
# Dream A Little Dream Of Me                           -0.560163 -0.009531
#
#                                                valence     tempo  duration_ms  \
# name
# All Shook Up                                  1.666362 -1.300917    -0.763678
# I've Got You Under My Skin - Remastered 1998  0.411614  0.376602    -0.295809
# Smoke Gets In Your Eyes                      -0.863989 -0.030729    -0.587315
# What'd I Say, Pt. 1 & 2                       1.117192 -0.850106     0.069490
# Dream A Little Dream Of Me                   -0.238353 -1.238292    -0.465506
#
#                                               time_signature
# name
# All Shook Up                                        0.247138
# I've Got You Under My Skin - Remastered 1998        0.247138
# Smoke Gets In Your Eyes                             0.247138
# What'd I Say, Pt. 1 & 2                             0.247138
# Dream A Little Dream Of Me                          0.247138

# %%
# Stating that we want two plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plotting the two plots
sns.histplot(data=music_df.iloc[:,6], bins=10, kde=True, ax=ax1);
sns.histplot(music_standard.iloc[:,6], bins=10, kde=True, ax=ax2);

# Adding titles to the plots
ax1.set_title('Distribution of x without scaling')
ax2.set_title('Distribution of x with Standard scaling')

plt.show()

# %% [markdown]
# ### Robust Scaling

# %%
# Import Robust Scaler
from sklearn.preprocessing import RobustScaler

# Create DataFrame of Robust scaled values
music_robust_df = RobustScaler().fit_transform(music_df)
music_robust = pd.DataFrame(music_robust_df, columns=music_df.columns, index=music_df.index)
music_robust.head()
# Out:
#                                               danceability    energy  \
# name
# All Shook Up                                      0.191210 -0.125510
# I've Got You Under My Skin - Remastered 1998      0.070933 -0.576531
# Smoke Gets In Your Eyes                          -0.838859 -0.617347
# What'd I Say, Pt. 1 & 2                          -0.067849  0.309184
# Dream A Little Dream Of Me                       -0.329992 -0.739796
#
#                                                    key  loudness  mode  \
# name
# All Shook Up                                  0.833333 -0.348378   0.0
# I've Got You Under My Skin - Remastered 1998 -0.666667 -0.397027   0.0
# Smoke Gets In Your Eyes                      -0.333333 -0.445459   0.0
# What'd I Say, Pt. 1 & 2                      -0.166667  0.378324   0.0
# Dream A Little Dream Of Me                   -0.833333 -0.505243   0.0
#
#                                               speechiness  acousticness  \
# name
# All Shook Up                                     1.661874      0.587618
# I've Got You Under My Skin - Remastered 1998    -0.162618      0.041973
# Smoke Gets In Your Eyes                         -0.339118      0.667748
# What'd I Say, Pt. 1 & 2                          0.051562      0.494769
# Dream A Little Dream Of Me                       0.509668      0.634678
#
#                                               instrumentalness  liveness  \
# name
# All Shook Up                                         -0.000755  0.231523
# I've Got You Under My Skin - Remastered 1998         -0.000740 -0.097952
# Smoke Gets In Your Eyes                              -0.000297  4.443455
# What'd I Say, Pt. 1 & 2                              -0.000795  0.391808
# Dream A Little Dream Of Me                           -0.000795  0.489760
#
#                                                valence     tempo  duration_ms  \
# name
# All Shook Up                                  0.941118 -0.804729    -1.013770
# I've Got You Under My Skin - Remastered 1998  0.226620  0.384585    -0.086380
# Smoke Gets In Your Eyes                      -0.499753  0.095798    -0.664191
# What'd I Say, Pt. 1 & 2                       0.628402 -0.485117     0.637702
# Dream A Little Dream Of Me                   -0.143493 -0.760330    -0.422746
#
#                                               time_signature
# name
# All Shook Up                                             0.0
# I've Got You Under My Skin - Remastered 1998             0.0
# Smoke Gets In Your Eyes                                  0.0
# What'd I Say, Pt. 1 & 2                                  0.0
# Dream A Little Dream Of Me                               0.0

# %%
# Stating that we want two plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plotting the two plots
sns.histplot(data=music_df.iloc[:,1], bins=10, kde=True, ax=ax1);
sns.histplot(music_robust.iloc[:,1], bins=10, kde=True, ax=ax2);

# Adding titles to the plots
ax1.set_title('Distribution of x without scaling')
ax2.set_title('Distribution of x with Robust scaling')

plt.show()

# %% [markdown]
# # Transformers

# %% [markdown]
# ### Quantile Transformer

# %%
# Import Quantile Transformer
from sklearn.preprocessing import QuantileTransformer

# Create DataFrame of Quantile transformed values
music_quantile_df = QuantileTransformer(n_quantiles=len(music_df.iloc[:,1])).fit_transform(music_df)
music_quantile = pd.DataFrame(music_quantile_df, columns=music_df.columns, index=music_df.index)
music_quantile.head()
# Out:
#                                               danceability    energy  \
# name
# All Shook Up                                      0.599375  0.442669
# I've Got You Under My Skin - Remastered 1998      0.537874  0.254343
# Smoke Gets In Your Eyes                           0.171994  0.235233
# What'd I Say, Pt. 1 & 2                           0.456915  0.681028
# Dream A Little Dream Of Me                        0.328006  0.184503
#
#                                                    key  loudness  mode  \
# name
# All Shook Up                                  0.897846  0.358582   1.0
# I've Got You Under My Skin - Remastered 1998  0.174079  0.340514   1.0
# Smoke Gets In Your Eyes                       0.336692  0.319666   1.0
# What'd I Say, Pt. 1 & 2                       0.397151  0.773801   1.0
# Dream A Little Dream Of Me                    0.000000  0.295344   1.0
#
#                                               speechiness  acousticness  \
# name
# All Shook Up                                     0.829743      0.763725
# I've Got You Under My Skin - Remastered 1998     0.301598      0.513204
# Smoke Gets In Your Eyes                          0.075400      0.857540
# What'd I Say, Pt. 1 & 2                          0.536831      0.692611
# Dream A Little Dream Of Me                       0.701181      0.807505
#
#                                               instrumentalness  liveness  \
# name
# All Shook Up                                          0.391244  0.617095
# I've Got You Under My Skin - Remastered 1998          0.407922  0.399931
# Smoke Gets In Your Eyes                               0.485059  0.970118
# What'd I Say, Pt. 1 & 2                               0.000000  0.674774
# Dream A Little Dream Of Me                            0.000000  0.701529
#
#                                                valence     tempo  duration_ms  \
# name
# All Shook Up                                  0.972898  0.066018     0.011119
# I've Got You Under My Skin - Remastered 1998  0.617443  0.672689     0.443363
# Smoke Gets In Your Eyes                       0.257123  0.537874     0.092425
# What'd I Say, Pt. 1 & 2                       0.828700  0.217512     0.747741
# Dream A Little Dream Of Me                    0.426338  0.083391     0.207088
#
#                                               time_signature
# name
# All Shook Up                                        0.545518
# I've Got You Under My Skin - Remastered 1998        0.545518
# Smoke Gets In Your Eyes                             0.545518
# What'd I Say, Pt. 1 & 2                             0.545518
# Dream A Little Dream Of Me                          0.545518

# %%
# Stating that we want two plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plotting the two plots
sns.histplot(data=music_df.iloc[:,7], bins=10, kde=True, ax=ax1);
sns.histplot(music_quantile.iloc[:,7], bins=10, kde=True, ax=ax2);

# Adding titles to the plots
ax1.set_title('Distribution of x without scaling')
ax2.set_title('Distribution of x with Quantile transforming')

plt.show()

# %% [markdown]
# ### Power Transformer

# %%
# Import Power Transformer
from sklearn.preprocessing import PowerTransformer

# Create DataFrame of Power transformed values
music_power_df = PowerTransformer().fit_transform(music_df)
music_power = pd.DataFrame(music_power_df, columns=music_df.columns, index=music_df.index)
music_power.head()
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())
#                                               danceability    energy  \
# name
# All Shook Up                                      0.335378 -0.109599
# I've Got You Under My Skin - Remastered 1998      0.145944 -0.883792
# Smoke Gets In Your Eyes                          -1.139156 -0.952770
# What'd I Say, Pt. 1 & 2                          -0.066967  0.655601
# Dream A Little Dream Of Me                       -0.452559 -1.158551
#
#                                                    key  loudness      mode  \
# name
# All Shook Up                                  1.266738 -0.408270  0.712638
# I've Got You Under My Skin - Remastered 1998 -1.191275 -0.468630  0.712638
# Smoke Gets In Your Eyes                      -0.497745 -0.526916  0.712638
# What'd I Say, Pt. 1 & 2                      -0.200441  0.839598  0.712638
# Dream A Little Dream Of Me                   -1.635960 -0.596539  0.712638
#
#                                               speechiness  acousticness  \
# name
# All Shook Up                                     1.320646      1.080623
# I've Got You Under My Skin - Remastered 1998    -0.697186      0.060800
# Smoke Gets In Your Eyes                         -1.110898      1.213502
# What'd I Say, Pt. 1 & 2                         -0.273048      0.921902
# Dream A Little Dream Of Me                       0.411145      1.159107
#
#                                               instrumentalness  liveness  \
# name
# All Shook Up                                         -0.641603  0.136925
# I've Got You Under My Skin - Remastered 1998         -0.641565 -0.403749
# Smoke Gets In Your Eyes                              -0.640486  1.956583
# What'd I Say, Pt. 1 & 2                              -0.641700  0.351287
# Dream A Little Dream Of Me                           -0.641700  0.469226
#
#                                                valence     tempo  duration_ms  \
# name
# All Shook Up                                  1.618541 -1.490412          0.0
# I've Got You Under My Skin - Remastered 1998  0.433906  0.501200          0.0
# Smoke Gets In Your Eyes                      -0.854239  0.110716          0.0
# What'd I Say, Pt. 1 & 2                       1.108664 -0.836612          0.0
# Dream A Little Dream Of Me                   -0.210198 -1.392132          0.0
#
#                                               time_signature
# name
# All Shook Up                                        0.172232
# I've Got You Under My Skin - Remastered 1998        0.172232
# Smoke Gets In Your Eyes                             0.172232
# What'd I Say, Pt. 1 & 2                             0.172232
# Dream A Little Dream Of Me                          0.172232

# %%
# Stating that we want two plots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 8))

# Plotting the two plots
sns.histplot(data=music_df.iloc[:,7], bins=10, kde=True, ax=ax1);
sns.histplot(data=music_power.iloc[:,7], bins=10, kde=True, ax=ax2);

# Adding titles to the plots
ax1.set_title('Distribution of x without scaling')
ax2.set_title('Distribution of x with Power transforming')

plt.show()

# %% [markdown]
# # SciKit Learn - Euclidean Distance

# %%
from sklearn.metrics import pairwise_distances
#not using scaling 
music_euclidean_distance = pd.DataFrame(pairwise_distances(music_df), index=music_df.index, columns=music_df.index)
music_euclidean_distance.head()
# Out:
# name                                           All Shook Up  \
# name
# All Shook Up                                       0.000000
# I've Got You Under My Skin - Remastered 1998  106680.013553
# Smoke Gets In Your Eyes                        40213.020664
# What'd I Say, Pt. 1 & 2                       189973.000748
# Dream A Little Dream Of Me                     67987.000783
#
# name                                          I've Got You Under My Skin - Remastered 1998  \
# name
# All Shook Up                                                                 106680.013553
# I've Got You Under My Skin - Remastered 1998                                      0.000000
# Smoke Gets In Your Eyes                                                       66467.001283
# What'd I Say, Pt. 1 & 2                                                       83293.009386
# Dream A Little Dream Of Me                                                    38693.033682
#
# name                                          Smoke Gets In Your Eyes  \
# name
# All Shook Up                                             40213.020664
# I've Got You Under My Skin - Remastered 1998             66467.001283
# Smoke Gets In Your Eyes                                      0.000000
# What'd I Say, Pt. 1 & 2                                 149760.002438
# Dream A Little Dream Of Me                               27774.026387
#
# name                                          What'd I Say, Pt. 1 & 2  \
# name
# All Shook Up                                            189973.000748
# I've Got You Under My Skin - Remastered 1998             83293.009386
# Smoke Gets In Your Eyes                                 149760.002438
# What'd I Say, Pt. 1 & 2                                      0.000000
# Dream A Little Dream Of Me                              121986.000958
#
# name                                          Dream A Little Dream Of Me  \
# name
# All Shook Up                                                67987.000783
# I've Got You Under My Skin - Remastered 1998                38693.033682
# Smoke Gets In Your Eyes                                     27774.026387
# What'd I Say, Pt. 1 & 2                                    121986.000958
# Dream A Little Dream Of Me                                      0.000000
#
# name                                          That'll Be The Day  \
# name
# All Shook Up                                        33053.026817
# I've Got You Under My Skin - Remastered 1998        73627.001130
# Smoke Gets In Your Eyes                              7160.002160
# What'd I Say, Pt. 1 & 2                            156920.002328
# Dream A Little Dream Of Me                          34934.022460
#
# name                                          Blueberry Hill  Mack the Knife  \
# name
# All Shook Up                                    30800.057029    67253.000926
# I've Got You Under My Skin - Remastered 1998    75880.000975    39427.025062
# Smoke Gets In Your Eyes                          9413.023394    27040.018412
# What'd I Say, Pt. 1 & 2                        159173.006563   122720.000329
# Dream A Little Dream Of Me                      37187.045877      734.038124
#
# name                                          All I Have to Do Is Dream  \
# name
# All Shook Up                                               24160.018915
# I've Got You Under My Skin - Remastered 1998               82520.003397
# Smoke Gets In Your Eyes                                    16053.003553
# What'd I Say, Pt. 1 & 2                                   165813.000930
# Dream A Little Dream Of Me                                 43827.008870
#
# name                                            Sea Of Love  ...  \
# name                                                         ...
# All Shook Up                                   27520.002493  ...
# I've Got You Under My Skin - Remastered 1998   79160.011221  ...
# Smoke Gets In Your Eyes                        12693.033430  ...
# What'd I Say, Pt. 1 & 2                       162453.000201  ...
# Dream A Little Dream Of Me                     40467.001700  ...
#
# name                                          Symphony No. 3 - "Chant de la nuit", Op. 27: Largo...  \
# name
# All Shook Up                                                                      472147.000364
# I've Got You Under My Skin - Remastered 1998                                      365467.001870
# Smoke Gets In Your Eyes                                                           431934.000673
# What'd I Say, Pt. 1 & 2                                                           282174.000344
# Dream A Little Dream Of Me                                                        404160.000374
#
# name                                          Pines Of Rome, P. 141: 3. The Pines Of The Janiculum  \
# name
# All Shook Up                                                                      284420.001494
# I've Got You Under My Skin - Remastered 1998                                      177740.003786
# Smoke Gets In Your Eyes                                                           244207.001379
# What'd I Say, Pt. 1 & 2                                                            94447.003731
# Dream A Little Dream Of Me                                                        216433.001607
#
# name                                          Don Giovanni, K.527: Overture  \
# name
# All Shook Up                                                  251880.006147
# I've Got You Under My Skin - Remastered 1998                  145200.000033
# Smoke Gets In Your Eyes                                       211667.000532
# What'd I Say, Pt. 1 & 2                                        61907.014121
# Dream A Little Dream Of Me                                    183893.007661
#
# name                                          Music for Strings, Percussion and Celesta, BB 114: II. Allegro  \
# name
# All Shook Up                                                                      326827.007290
# I've Got You Under My Skin - Remastered 1998                                      220147.000993
# Smoke Gets In Your Eyes                                                           286614.001654
# What'd I Say, Pt. 1 & 2                                                           136854.011921
# Dream A Little Dream Of Me                                                        258840.008866
#
# name                                          A Flock Descends Into The Pentagonal Garden  \
# name
# All Shook Up                                                                657627.000287
# I've Got You Under My Skin - Remastered 1998                                550947.004070
# Smoke Gets In Your Eyes                                                     617414.002382
# What'd I Say, Pt. 1 & 2                                                     467654.001206
# Dream A Little Dream Of Me                                                  589640.000316
#
# name                                          1812 Festival Overture, Op. 49: 1812 Overture, Op. 49  \
# name
# All Shook Up                                                                      877920.000209
# I've Got You Under My Skin - Remastered 1998                                      771240.001077
# Smoke Gets In Your Eyes                                                           837707.000479
# What'd I Say, Pt. 1 & 2                                                           687947.000236
# Dream A Little Dream Of Me                                                        809933.000151
#
# name                                          Winter Fragments pour ensemble instrumental, sons de synthèse et dispositif électronique  \
# name
# All Shook Up                                                                      737920.000130
# I've Got You Under My Skin - Remastered 1998                                      631240.001623
# Smoke Gets In Your Eyes                                                           697707.000758
# What'd I Say, Pt. 1 & 2                                                           547947.000276
# Dream A Little Dream Of Me                                                        669933.000115
#
# name                                          Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3 Farben (Colours)  \
# name
# All Shook Up                                                                      121107.003961
# I've Got You Under My Skin - Remastered 1998                                       14427.141282
# Smoke Gets In Your Eyes                                                            80894.017035
# What'd I Say, Pt. 1 & 2                                                            68866.012478
# Dream A Little Dream Of Me                                                         53120.009084
#
# name                                          Serenade For Strings In E, Op.22, B. 52: 1. Moderato  \
# name
# All Shook Up                                                                      197227.000977
# I've Got You Under My Skin - Remastered 1998                                       90547.021526
# Smoke Gets In Your Eyes                                                           157014.007945
# What'd I Say, Pt. 1 & 2                                                             7254.071010
# Dream A Little Dream Of Me                                                        129240.001347
#
# name                                          Ravel: Boléro, M. 81
# name
# All Shook Up                                         831707.000169
# I've Got You Under My Skin - Remastered 1998         725027.002850
# Smoke Gets In Your Eyes                              791494.001676
# What'd I Say, Pt. 1 & 2                              641734.000746
# Dream A Little Dream Of Me                           763720.000190
#
# [5 rows x 1440 columns]

# %% [markdown]
# # K-Means (Comparing Two Parts of Data) (MinMax Scaler)

# %% [markdown]
# ### Visualise the Data

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.scatterplot(data=music_df, x='danceability', y='energy')
plt.title('Looking for a relation between x and x')
plt.show()

# %% [markdown]
# ### Data Scaling

# %%
#if only comparing two varibles use 
music_two = music_df[['danceability','energy']]
music_two.head()
# Out:
#                                               danceability  energy
# name
# All Shook Up                                         0.624   0.468
# I've Got You Under My Skin - Remastered 1998         0.585   0.247
# Smoke Gets In Your Eyes                              0.290   0.227
# What'd I Say, Pt. 1 & 2                              0.540   0.681
# Dream A Little Dream Of Me                           0.455   0.167

# %%
music_two.describe()
# Out:
#        danceability       energy
# count   1440.000000  1440.000000
# mean       0.538917     0.494241
# std        0.219193     0.281917
# min        0.059600     0.000020
# 25%        0.386000     0.243000
# 50%        0.562000     0.529500
# 75%        0.710250     0.733000
# max        0.964000     0.996000

# %%
from sklearn.preprocessing import MinMaxScaler

music_two_scaled = MinMaxScaler().fit_transform(music_two)

# %%
type(music_two_scaled)
# Out:
# numpy.ndarray

# %%
music_two_scaled = pd.DataFrame(music_two_scaled) #turn it back into a dataframe
music_two_scaled.columns = ['danceability','energy']
music_two_scaled[:5]
# Out:
#    danceability    energy
# 0      0.624060  0.469869
# 1      0.580938  0.247977
# 2      0.254755  0.227896
# 3      0.531181  0.683728
# 4      0.437196  0.167654

# %% [markdown]
# ### K-Means

# %%
from sklearn.cluster import KMeans

# Based on the quick look to the scatter plot, 
# we are going to assume there can be 2 different clusters k = 3. 
kmeans = KMeans(n_clusters=2)
kmeans.fit(music_two_scaled)  # Compute k-means clustering
# Out:
# KMeans(n_clusters=2)

# %%
kmeans.cluster_centers_
# Out:
# array([[0.66287863, 0.6863126 ],
#        [0.32417248, 0.20181711]])

# %%
cl_pos = pd.DataFrame(kmeans.cluster_centers_)
cl_pos.columns = ['danceability','energy']
cl_pos
# Out:
#    danceability    energy
# 0      0.662879  0.686313
# 1      0.324172  0.201817

# %% [markdown]
# ### K-Means Plot

# %%
# create plot dataframe
plot_data = pd.DataFrame(music_two_scaled)
plot_data.columns = ['danceability','energy']
plot_data['cluster'] = kmeans.labels_

# size and plot titles
fig, ax = plt.subplots(figsize=(10, 8))
plt.title('Visualising clusters')
plt.xlabel('danceability normalised')
plt.ylabel('energy normalised')

# scatter plot
sns.scatterplot(data=plot_data, x='danceability', y='energy', hue='cluster', palette='Set2', s=75)
sns.scatterplot(data=cl_pos, x='danceability', y='energy', color='red', s=250)
plt.show()

# %% [markdown]
# # K-Means (All Data) (Standard Scaler)

# %%
from sklearn.preprocessing import StandardScaler
music_df_standard = StandardScaler().fit_transform(music_df)

kmeans_all = KMeans(n_clusters=3)
kmeans_all.fit(music_df_standard)
# Out:
# KMeans(n_clusters=3)

# %%
kmeans_all.cluster_centers_
# Out:
# array([[-1.27199402, -1.22619608, -0.02915516, -1.48764013, -0.09935784,
#         -0.49458169,  1.14233418,  1.75344149, -0.10856469, -1.2005741 ,
#         -0.47313663,  0.96972474, -0.45489007],
#        [ 0.58532687,  0.75340586,  0.01678802,  0.65026017, -0.02144062,
#          0.39762808, -0.76924677, -0.43092164,  0.06136206,  0.53340403,
#          0.20378767, -0.24930064,  0.22715375],
#        [-0.29658672, -0.67109365, -0.01366432, -0.27702207,  0.1135985 ,
#         -0.46158123,  0.76238157, -0.35672748, -0.04853719, -0.24112513,
#         -0.08194676, -0.1749187 , -0.14237229]])

# %% [markdown]
# ### Plot 1 (2D)

# %%
cl_pos = pd.DataFrame(kmeans_all.cluster_centers_)
cl_pos.columns = ['danceability',	'energy',	'key',	'loudness',	'mode',	'speechiness',	'acousticness',	'instrumentalness', 'liveness',	'valence', 'tempo',	'duration_ms',	'time_signature']
cl_pos

fig, ax = plt.subplots(figsize=(10, 8))

plot_data = pd.DataFrame(music_df_standard)
plot_data.columns = ['danceability',	'energy',	'key',	'loudness',	'mode',	'speechiness',	'acousticness',	'instrumentalness', 'liveness',	'valence', 'tempo',	'duration_ms',	'time_signature']
plot_data['cluster'] = kmeans_all.labels_

sns.scatterplot(data=plot_data, x='danceability', y='energy', hue='cluster', palette='Set2', s=75)
sns.scatterplot(data=cl_pos, x='danceability', y='energy', color='red', s=250)
plt.show()

# %% [markdown]
# ### Plot 2 (3D)

# %%
import matplotlib.pyplot as plt
import random
colors = ['r','g','b']
markers = ['o', '^','s']
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(projection='3d')

# ax.scatter(plot_data['bill_depth_mm'], plot_data['bill_length_mm'], plot_data['flipper_length_mm'])
for marker, d in plot_data.groupby('cluster'):
    ax.scatter(d['danceability'], d['energy'], d['key'], marker=markers[marker], label=d['cluster'])
ax.scatter(cl_pos['danceability'], cl_pos['energy'],cl_pos['key'], color='red', s=250)
ax.set_xlabel('danceability')
ax.set_ylabel('energy')
ax.set_zlabel('key')
plt.show()

# %% [markdown]
# ### Plot 3 (all data)

# %%
# Source: https://www.python-graph-gallery.com/391-radar-chart-with-several-individuals
# Libraries
from math import pi
 
# Set data
radar_df = cl_pos.reset_index().rename(columns={'index':'cluster'})
 
# ------- PART 1: Create background
 
# number of variable
categories= radar_df.columns.tolist()[1:]
# list(df)[1:]
N = len(categories)
 
# What will be the angle of each axis in the plot? (we divide the plot / number of variable)
angles = [n / float(N) * 2 * pi for n in range(N)]
angles += angles[:1]
 
# Initialise the spider plot
ax = plt.subplot(111, polar=True)
 
# If you want the first axis to be on top:
ax.set_theta_offset(pi / 2)
ax.set_theta_direction(-1)
 
# Draw one axe per variable + add labels
plt.xticks(angles[:-1], categories)
 
# Draw ylabels
ax.set_rlabel_position(0)
plt.yticks(ticks=None, labels=None)
# plt.ylim(0,40)
 

# ------- PART 2: Add plots
 
# Plot each individual = each line of the data
# I don't make a loop, because plotting more than 3 groups makes the chart unreadable

# Ind1
values=radar_df.loc[0].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 0")
ax.fill(angles, values, 'b', alpha=0.1)

# Ind2
values=radar_df.loc[1].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 1")
ax.fill(angles, values, 'r', alpha=0.1)

# Ind3
values=radar_df.loc[2].drop('cluster').values.flatten().tolist()
values += values[:1]
ax.plot(angles, values, linewidth=1, linestyle=None, label="Cluster 2")
ax.fill(angles, values, 'b', alpha=0.1)

# # Add legend
plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# Show the graph
plt.show()

# %% [markdown]
# # K-Means Choosing Clusters

# %% [markdown]
# ### Elbow Method - Using inertia

# %%
from sklearn.preprocessing import StandardScaler
music_df_standard = StandardScaler().fit_transform(music_df)

kmeans_all = KMeans(n_clusters=3)
music_kmeans = kmeans_all.fit(music_df_standard)

# %%
music_kmeans.inertia_
# Out:
# 12483.879511290761

# %%
max_k = 15
inertia = []

for k in range(1, max_k): 
    inertia.append(KMeans(n_clusters=k).fit(music_df).inertia_)

fig, ax = plt.subplots(figsize=(12, 6))
plt.title(f'Inertia evolution from 1 cluster to {max_k} cluster')
sns.lineplot(x=range(1, max_k), y=inertia, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.show()

# %% [markdown]
# ### Silhouette Method

# %%
from sklearn.metrics import silhouette_score
silhouette_score(music_df, music_kmeans.labels_)
# Out:
# 0.022761226687838212

# %%
max_k = 15
sil_score = []

food_norm = MinMaxScaler().fit_transform(music_df)

for k in range(2, max_k): 
    labels = KMeans(n_clusters=k).fit(music_df).labels_
    sil_score.append(silhouette_score(music_df, labels))

plt.title(f'Silhouette score evolution from 2 cluster to {max_k} clusters')
sns.lineplot(x=range(2, max_k), y=sil_score, marker='o')
plt.show()
